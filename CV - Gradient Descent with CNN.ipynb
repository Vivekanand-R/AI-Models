# %% [markdown]
# Goal: To understand list of Gradient Descent Techniques in detail

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Start with MNIST (Hardwritten Digit Classifications)**
#
# Total Training Samples: 60000; Total Test Samples: 10000

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
import random

# Set seeds
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# Load MNIST data
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transform, download=True)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)

# CNN model
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.fc1 = nn.Linear(16*5*5, 64)
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 16*5*5)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Utility functions
def get_param_vector(model):
    return torch.cat([p.data.view(-1) for p in model.parameters()])

def predict_samples(model, dataset, num=5):
    model.eval()
    fig, axes = plt.subplots(1, num, figsize=(12, 3))
    for i in range(num):
        image, label = dataset[i]
        input_img = image.unsqueeze(0)
        output = model(input_img)
        pred = torch.argmax(output, dim=1).item()
        axes[i].imshow(image.squeeze(), cmap='gray')
        axes[i].set_title(f"True: {label}\nPred: {pred}")
        axes[i].axis('off')
    plt.suptitle("Sample Predictions")
    plt.show()

# Train model and print internal state
def train_and_track(optimizer_name, model, train_loader, criterion, epochs=5):
    model.train()
    param_trajectory = []
    loss_trajectory = []

    if optimizer_name == 'GD':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
        use_batches = False
    elif optimizer_name == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
        use_batches = True
    elif optimizer_name == 'Momentum':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
        use_batches = True
    elif optimizer_name == 'RMSProp':
        optimizer = torch.optim.RMSprop(model.parameters(), lr=0.001)
        use_batches = True
    elif optimizer_name == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        use_batches = True
    elif optimizer_name == 'Adagrad':
        optimizer = torch.optim.Adagrad(model.parameters(), lr=0.01)
        use_batches = True
    else:
        raise ValueError("Unsupported optimizer")

    print(f"\nTraining with optimizer: {optimizer_name}")
    for epoch in range(epochs):
        running_loss = 0.0
        first_batch = True

        if not use_batches:
            images, labels = next(iter(train_loader))
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss = loss.item()
        else:
            for images, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(images)
                loss = criterion(outputs, labels)
                loss.backward()

                if first_batch:
                    print(f"\nEpoch {epoch+1} (Optimizer: {optimizer_name})")
                    for name, param in model.named_parameters():
                        if param.grad is not None:
                            print(f"  ∇J({name}) = grad norm: {param.grad.norm():.6f}")
                    for group in optimizer.param_groups:
                        for p in group['params']:
                            state = optimizer.state[p]
                            if optimizer_name == 'Momentum' and 'momentum_buffer' in state:
                                v = state['momentum_buffer']
                                print(f"  v (momentum) mean: {v.mean().item():.6f}")
                            if optimizer_name == 'RMSProp' and 'square_avg' in state:
                                s = state['square_avg']
                                print(f"  s (RMSProp avg^2) mean: {s.mean().item():.6f}")
                            if optimizer_name == 'Adam' and 'exp_avg' in state:
                                m = state['exp_avg']
                                v = state['exp_avg_sq']
                                print(f"  mₜ (Adam 1st moment) mean: {m.mean().item():.6f}")
                                print(f"  vₜ (Adam 2nd moment) mean: {v.mean().item():.6f}")
                            if optimizer_name == 'Adagrad' and 'sum' in state:
                                G = state['sum']
                                print(f"  Gₜ (Adagrad sum of grads²) mean: {G.mean().item():.6f}")
                    first_batch = False

                optimizer.step()
                running_loss += loss.item()

        avg_loss = running_loss / (1 if not use_batches else len(train_loader))
        print(f"Epoch [{epoch+1}/{epochs}] J(θ) = {avg_loss:.4f}")

        param_vector = get_param_vector(model).detach().cpu().numpy()
        param_trajectory.append(param_vector)
        loss_trajectory.append(avg_loss)

    return np.array(param_trajectory), np.array(loss_trajectory), model

# Accuracy eval
def evaluate(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# Run training for all optimizers
optimizers = ['GD', 'SGD', 'Momentum', 'RMSProp', 'Adam', 'Adagrad']
trajectories = {}
criterion = nn.CrossEntropyLoss()

for opt_name in optimizers:
    model = SimpleCNN()
    traj, losses, trained_model = train_and_track(opt_name, model, train_loader, criterion, epochs=5)
    trajectories[opt_name] = {'trajectory': traj, 'losses': losses, 'model': trained_model}

# 2D Loss plot
plt.figure(figsize=(10, 6))
for opt_name in optimizers:
    losses = trajectories[opt_name]['losses']
    plt.plot(range(1, len(losses)+1), losses, label=opt_name)
plt.xlabel('Epoch')
plt.ylabel('Loss J(θ)')
plt.title('Loss vs Epochs for Different Optimizers')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 3D PCA Trajectory
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
for opt_name in optimizers:
    traj = trajectories[opt_name]['trajectory']
    pca = PCA(n_components=2)
    reduced = pca.fit_transform(traj)
    z = trajectories[opt_name]['losses']
    ax.plot(reduced[:, 0], reduced[:, 1], z, label=opt_name)
ax.set_title('3D Optimization Trajectory (PCA + J(θ))')
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel('Loss J(θ)')
ax.legend()
plt.tight_layout()
plt.show()

# Final evaluation
accuracy = evaluate(trained_model, test_loader)
print(f"\nFinal Test Accuracy: {accuracy * 100:.2f}%")
predict_samples(trained_model, test_dataset)
# Out:
# Training with optimizer: GD
# Epoch [1/5] J(θ) = 2.2926
# Epoch [2/5] J(θ) = 2.3080
# Epoch [3/5] J(θ) = 2.3167
# Epoch [4/5] J(θ) = 2.2967
# Epoch [5/5] J(θ) = 2.3090
#
# Training with optimizer: SGD
#
# Epoch 1 (Optimizer: SGD)
#   ∇J(conv1.weight) = grad norm: 0.022044
#   ∇J(conv1.bias) = grad norm: 0.009998
#   ∇J(conv2.weight) = grad norm: 0.120499
#   ∇J(conv2.bias) = grad norm: 0.037005
#   ∇J(fc1.weight) = grad norm: 0.241853
#   ∇J(fc1.bias) = grad norm: 0.065955
#   ∇J(fc2.weight) = grad norm: 0.086044
#   ∇J(fc2.bias) = grad norm: 0.142814
# Epoch [1/5] J(θ) = 1.4147
#
# Epoch 2 (Optimizer: SGD)
#   ∇J(conv1.weight) = grad norm: 0.084576
#   ∇J(conv1.bias) = grad norm: 0.182728
#   ∇J(conv2.weight) = grad norm: 0.516141
#   ∇J(conv2.bias) = grad norm: 0.074766
#   ∇J(fc1.weight) = grad norm: 5.643419
#   ∇J(fc1.bias) = grad norm: 0.095816
#   ∇J(fc2.weight) = grad norm: 4.462295
#   ∇J(fc2.bias) = grad norm: 0.175554
# Epoch [2/5] J(θ) = 0.3455
#
# Epoch 3 (Optimizer: SGD)
#   ∇J(conv1.weight) = grad norm: 0.086136
#   ∇J(conv1.bias) = grad norm: 0.016751
#   ∇J(conv2.weight) = grad norm: 0.190168
#   ∇J(conv2.bias) = grad norm: 0.019483
#   ∇J(fc1.weight) = grad norm: 1.510666
#   ∇J(fc1.bias) = grad norm: 0.024204
#   ∇J(fc2.weight) = grad norm: 0.791311
#   ∇J(fc2.bias) = grad norm: 0.032258
# Epoch [3/5] J(θ) = 0.2352
#
# Epoch 4 (Optimizer: SGD)
#   ∇J(conv1.weight) = grad norm: 0.038238
#   ∇J(conv1.bias) = grad norm: 0.029098
#   ∇J(conv2.weight) = grad norm: 0.263106
#   ∇J(conv2.bias) = grad norm: 0.022018
#   ∇J(fc1.weight) = grad norm: 2.406522
#   ∇J(fc1.bias) = grad norm: 0.034217
#   ∇J(fc2.weight) = grad norm: 0.958480
#   ∇J(fc2.bias) = grad norm: 0.035914
# Epoch [4/5] J(θ) = 0.1774
#
# Epoch 5 (Optimizer: SGD)
#   ∇J(conv1.weight) = grad norm: 0.076966
#   ∇J(conv1.bias) = grad norm: 0.061949
#   ∇J(conv2.weight) = grad norm: 0.485723
#   ∇J(conv2.bias) = grad norm: 0.050155
#   ∇J(fc1.weight) = grad norm: 2.719764
#   ∇J(fc1.bias) = grad norm: 0.037842
#   ∇J(fc2.weight) = grad norm: 1.366262
#   ∇J(fc2.bias) = grad norm: 0.044662
# Epoch [5/5] J(θ) = 0.1421
#
# Training with optimizer: Momentum
#
# Epoch 1 (Optimizer: Momentum)
#   ∇J(conv1.weight) = grad norm: 0.027169
#   ∇J(conv1.bias) = grad norm: 0.017168
#   ∇J(conv2.weight) = grad norm: 0.107672
#   ∇J(conv2.bias) = grad norm: 0.033497
#   ∇J(fc1.weight) = grad norm: 0.329490
#   ∇J(fc1.bias) = grad norm: 0.064286
#   ∇J(fc2.weight) = grad norm: 0.117065
#   ∇J(fc2.bias) = grad norm: 0.148996
# Epoch [1/5] J(θ) = 0.3770
#
# Epoch 2 (Optimizer: Momentum)
#   ∇J(conv1.weight) = grad norm: 0.156506
#   ∇J(conv1.bias) = grad norm: 0.100053
#   ∇J(conv2.weight) = grad norm: 0.712673
#   ∇J(conv2.bias) = grad norm: 0.068823
#   ∇J(fc1.weight) = grad norm: 1.422830
#   ∇J(fc1.bias) = grad norm: 0.046315
#   ∇J(fc2.weight) = grad norm: 0.568536
#   ∇J(fc2.bias) = grad norm: 0.045001
#   v (momentum) mean: 0.003920
#   v (momentum) mean: -0.009884
#   v (momentum) mean: 0.002547
#   v (momentum) mean: 0.001128
#   v (momentum) mean: 0.001623
#   v (momentum) mean: 0.001432
#   v (momentum) mean: 0.000000
#   v (momentum) mean: 0.000000
# Epoch [2/5] J(θ) = 0.0881
#
# Epoch 3 (Optimizer: Momentum)
#   ∇J(conv1.weight) = grad norm: 0.050419
#   ∇J(conv1.bias) = grad norm: 0.016155
#   ∇J(conv2.weight) = grad norm: 0.263668
#   ∇J(conv2.bias) = grad norm: 0.026055
#   ∇J(fc1.weight) = grad norm: 0.696853
#   ∇J(fc1.bias) = grad norm: 0.021441
#   ∇J(fc2.weight) = grad norm: 0.332325
#   ∇J(fc2.bias) = grad norm: 0.018901
#   v (momentum) mean: -0.008844
#   v (momentum) mean: -0.024595
#   v (momentum) mean: -0.004659
#   v (momentum) mean: -0.004775
#   v (momentum) mean: 0.000356
#   v (momentum) mean: 0.000236
#   v (momentum) mean: 0.000000
#   v (momentum) mean: 0.000000
# Epoch [3/5] J(θ) = 0.0658
#
# Epoch 4 (Optimizer: Momentum)
#   ∇J(conv1.weight) = grad norm: 0.045016
#   ∇J(conv1.bias) = grad norm: 0.022363
#   ∇J(conv2.weight) = grad norm: 0.196384
#   ∇J(conv2.bias) = grad norm: 0.026048
#   ∇J(fc1.weight) = grad norm: 0.475851
#   ∇J(fc1.bias) = grad norm: 0.017717
#   ∇J(fc2.weight) = grad norm: 0.291394
#   ∇J(fc2.bias) = grad norm: 0.015867
#   v (momentum) mean: -0.002916
#   v (momentum) mean: -0.005043
#   v (momentum) mean: -0.000003
#   v (momentum) mean: -0.000639
#   v (momentum) mean: -0.000049
#   v (momentum) mean: -0.000174
#   v (momentum) mean: 0.000000
#   v (momentum) mean: 0.000000
# Epoch [4/5] J(θ) = 0.0511
#
# Epoch 5 (Optimizer: Momentum)
#   ∇J(conv1.weight) = grad norm: 0.015475
#   ∇J(conv1.bias) = grad norm: 0.005517
#   ∇J(conv2.weight) = grad norm: 0.035752
#   ∇J(conv2.bias) = grad norm: 0.002599
#   ∇J(fc1.weight) = grad norm: 0.080058
#   ∇J(fc1.bias) = grad norm: 0.002600
#   ∇J(fc2.weight) = grad norm: 0.046367
#   ∇J(fc2.bias) = grad norm: 0.002750
#   v (momentum) mean: 0.001061
#   v (momentum) mean: 0.014156
#   v (momentum) mean: 0.001674
#   v (momentum) mean: 0.000465
#   v (momentum) mean: 0.000269
#   v (momentum) mean: 0.000217
#   v (momentum) mean: -0.000000
#   v (momentum) mean: -0.000000
# Epoch [5/5] J(θ) = 0.0438
#
# Training with optimizer: RMSProp
#
# Epoch 1 (Optimizer: RMSProp)
#   ∇J(conv1.weight) = grad norm: 0.019216
#   ∇J(conv1.bias) = grad norm: 0.011833
#   ∇J(conv2.weight) = grad norm: 0.049778
#   ∇J(conv2.bias) = grad norm: 0.034488
#   ∇J(fc1.weight) = grad norm: 0.160460
#   ∇J(fc1.bias) = grad norm: 0.065061
#   ∇J(fc2.weight) = grad norm: 0.068073
#   ∇J(fc2.bias) = grad norm: 0.131265
# Epoch [1/5] J(θ) = 0.2257
#
# Epoch 2 (Optimizer: RMSProp)
#   ∇J(conv1.weight) = grad norm: 0.204014
#   ∇J(conv1.bias) = grad norm: 0.195506
#   ∇J(conv2.weight) = grad norm: 0.622175
#   ∇J(conv2.bias) = grad norm: 0.107018
#   ∇J(fc1.weight) = grad norm: 0.979317
#   ∇J(fc1.bias) = grad norm: 0.038792
#   ∇J(fc2.weight) = grad norm: 1.546736
#   ∇J(fc2.bias) = grad norm: 0.056345
#   s (RMSProp avg^2) mean: 0.000616
#   s (RMSProp avg^2) mean: 0.003140
#   s (RMSProp avg^2) mean: 0.000182
#   s (RMSProp avg^2) mean: 0.000251
#   s (RMSProp avg^2) mean: 0.000017
#   s (RMSProp avg^2) mean: 0.000009
#   s (RMSProp avg^2) mean: 0.001575
#   s (RMSProp avg^2) mean: 0.000111
# Epoch [2/5] J(θ) = 0.0888
#
# Epoch 3 (Optimizer: RMSProp)
#   ∇J(conv1.weight) = grad norm: 0.119471
#   ∇J(conv1.bias) = grad norm: 0.108547
#   ∇J(conv2.weight) = grad norm: 0.265110
#   ∇J(conv2.bias) = grad norm: 0.042861
#   ∇J(fc1.weight) = grad norm: 0.268628
#   ∇J(fc1.bias) = grad norm: 0.011871
#   ∇J(fc2.weight) = grad norm: 0.309212
#   ∇J(fc2.bias) = grad norm: 0.013159
#   s (RMSProp avg^2) mean: 0.000683
#   s (RMSProp avg^2) mean: 0.003644
#   s (RMSProp avg^2) mean: 0.000190
#   s (RMSProp avg^2) mean: 0.000214
#   s (RMSProp avg^2) mean: 0.000014
#   s (RMSProp avg^2) mean: 0.000007
#   s (RMSProp avg^2) mean: 0.000955
#   s (RMSProp avg^2) mean: 0.000072
# Epoch [3/5] J(θ) = 0.0650
#
# Epoch 4 (Optimizer: RMSProp)
#   ∇J(conv1.weight) = grad norm: 0.112879
#   ∇J(conv1.bias) = grad norm: 0.068780
#   ∇J(conv2.weight) = grad norm: 0.209811
#   ∇J(conv2.bias) = grad norm: 0.025137
#   ∇J(fc1.weight) = grad norm: 0.309225
#   ∇J(fc1.bias) = grad norm: 0.012427
#   ∇J(fc2.weight) = grad norm: 0.456939
#   ∇J(fc2.bias) = grad norm: 0.017785
#   s (RMSProp avg^2) mean: 0.000529
#   s (RMSProp avg^2) mean: 0.002474
#   s (RMSProp avg^2) mean: 0.000156
#   s (RMSProp avg^2) mean: 0.000168
#   s (RMSProp avg^2) mean: 0.000010
#   s (RMSProp avg^2) mean: 0.000005
#   s (RMSProp avg^2) mean: 0.000625
#   s (RMSProp avg^2) mean: 0.000051
# Epoch [4/5] J(θ) = 0.0523
#
# Epoch 5 (Optimizer: RMSProp)
#   ∇J(conv1.weight) = grad norm: 0.278273
#   ∇J(conv1.bias) = grad norm: 0.171523
#   ∇J(conv2.weight) = grad norm: 0.495292
#   ∇J(conv2.bias) = grad norm: 0.042267
#   ∇J(fc1.weight) = grad norm: 0.371655
#   ∇J(fc1.bias) = grad norm: 0.012633
#   ∇J(fc2.weight) = grad norm: 0.426790
#   ∇J(fc2.bias) = grad norm: 0.013240
#   s (RMSProp avg^2) mean: 0.000413
#   s (RMSProp avg^2) mean: 0.002048
#   s (RMSProp avg^2) mean: 0.000141
#   s (RMSProp avg^2) mean: 0.000147
#   s (RMSProp avg^2) mean: 0.000009
#   s (RMSProp avg^2) mean: 0.000005
#   s (RMSProp avg^2) mean: 0.000505
#   s (RMSProp avg^2) mean: 0.000041
# Epoch [5/5] J(θ) = 0.0431
#
# Training with optimizer: Adam
#
# Epoch 1 (Optimizer: Adam)
#   ∇J(conv1.weight) = grad norm: 0.015660
#   ∇J(conv1.bias) = grad norm: 0.014671
#   ∇J(conv2.weight) = grad norm: 0.048165
#   ∇J(conv2.bias) = grad norm: 0.028068
#   ∇J(fc1.weight) = grad norm: 0.131345
#   ∇J(fc1.bias) = grad norm: 0.058366
#   ∇J(fc2.weight) = grad norm: 0.055523
#   ∇J(fc2.bias) = grad norm: 0.133698
# Epoch [1/5] J(θ) = 0.3070
#
# Epoch 2 (Optimizer: Adam)
#   ∇J(conv1.weight) = grad norm: 0.151789
#   ∇J(conv1.bias) = grad norm: 0.147886
#   ∇J(conv2.weight) = grad norm: 0.206972
#   ∇J(conv2.bias) = grad norm: 0.047323
#   ∇J(fc1.weight) = grad norm: 0.293749
#   ∇J(fc1.bias) = grad norm: 0.015864
#   ∇J(fc2.weight) = grad norm: 0.342310
#   ∇J(fc2.bias) = grad norm: 0.016207
#   mₜ (Adam 1st moment) mean: -0.000518
#   vₜ (Adam 2nd moment) mean: 0.000572
#   mₜ (Adam 1st moment) mean: -0.000134
#   vₜ (Adam 2nd moment) mean: 0.002958
#   mₜ (Adam 1st moment) mean: 0.000211
#   vₜ (Adam 2nd moment) mean: 0.000079
#   mₜ (Adam 1st moment) mean: 0.000553
#   vₜ (Adam 2nd moment) mean: 0.000307
#   mₜ (Adam 1st moment) mean: -0.000008
#   vₜ (Adam 2nd moment) mean: 0.000013
#   mₜ (Adam 1st moment) mean: -0.000018
#   vₜ (Adam 2nd moment) mean: 0.000011
#   mₜ (Adam 1st moment) mean: -0.000000
#   vₜ (Adam 2nd moment) mean: 0.001086
#   mₜ (Adam 1st moment) mean: -0.000000
#   vₜ (Adam 2nd moment) mean: 0.000133
# Epoch [2/5] J(θ) = 0.0869
#
# Epoch 3 (Optimizer: Adam)
#   ∇J(conv1.weight) = grad norm: 0.282048
#   ∇J(conv1.bias) = grad norm: 0.286948
#   ∇J(conv2.weight) = grad norm: 0.509803
#   ∇J(conv2.bias) = grad norm: 0.120798
#   ∇J(fc1.weight) = grad norm: 0.592326
#   ∇J(fc1.bias) = grad norm: 0.026109
#   ∇J(fc2.weight) = grad norm: 0.949122
#   ∇J(fc2.bias) = grad norm: 0.033000
#   mₜ (Adam 1st moment) mean: 0.000376
#   vₜ (Adam 2nd moment) mean: 0.000683
#   mₜ (Adam 1st moment) mean: 0.001534
#   vₜ (Adam 2nd moment) mean: 0.003517
#   mₜ (Adam 1st moment) mean: -0.000240
#   vₜ (Adam 2nd moment) mean: 0.000108
#   mₜ (Adam 1st moment) mean: -0.000731
#   vₜ (Adam 2nd moment) mean: 0.000336
#   mₜ (Adam 1st moment) mean: -0.000008
#   vₜ (Adam 2nd moment) mean: 0.000012
#   mₜ (Adam 1st moment) mean: -0.000033
#   vₜ (Adam 2nd moment) mean: 0.000009
#   mₜ (Adam 1st moment) mean: -0.000000
#   vₜ (Adam 2nd moment) mean: 0.000932
#   mₜ (Adam 1st moment) mean: -0.000000
#   vₜ (Adam 2nd moment) mean: 0.000098
# Epoch [3/5] J(θ) = 0.0616
#
# Epoch 4 (Optimizer: Adam)
#   ∇J(conv1.weight) = grad norm: 0.157922
#   ∇J(conv1.bias) = grad norm: 0.066570
#   ∇J(conv2.weight) = grad norm: 0.375530
#   ∇J(conv2.bias) = grad norm: 0.047230
#   ∇J(fc1.weight) = grad norm: 0.529248
#   ∇J(fc1.bias) = grad norm: 0.024576
#   ∇J(fc2.weight) = grad norm: 0.655438
#   ∇J(fc2.bias) = grad norm: 0.028665
#   mₜ (Adam 1st moment) mean: -0.001175
#   vₜ (Adam 2nd moment) mean: 0.000670
#   mₜ (Adam 1st moment) mean: -0.001395
#   vₜ (Adam 2nd moment) mean: 0.003258
#   mₜ (Adam 1st moment) mean: -0.000140
#   vₜ (Adam 2nd moment) mean: 0.000112
#   mₜ (Adam 1st moment) mean: -0.000297
#   vₜ (Adam 2nd moment) mean: 0.000291
#   mₜ (Adam 1st moment) mean: -0.000027
#   vₜ (Adam 2nd moment) mean: 0.000010
#   mₜ (Adam 1st moment) mean: -0.000040
#   vₜ (Adam 2nd moment) mean: 0.000007
#   mₜ (Adam 1st moment) mean: -0.000000
#   vₜ (Adam 2nd moment) mean: 0.000717
#   mₜ (Adam 1st moment) mean: 0.000000
#   vₜ (Adam 2nd moment) mean: 0.000070
# Epoch [4/5] J(θ) = 0.0493
#
# Epoch 5 (Optimizer: Adam)
#   ∇J(conv1.weight) = grad norm: 0.033927
#   ∇J(conv1.bias) = grad norm: 0.032593
#   ∇J(conv2.weight) = grad norm: 0.097220
#   ∇J(conv2.bias) = grad norm: 0.018843
#   ∇J(fc1.weight) = grad norm: 0.164257
#   ∇J(fc1.bias) = grad norm: 0.008054
#   ∇J(fc2.weight) = grad norm: 0.197380
#   ∇J(fc2.bias) = grad norm: 0.007851
#   mₜ (Adam 1st moment) mean: 0.001789
#   vₜ (Adam 2nd moment) mean: 0.000605
#   mₜ (Adam 1st moment) mean: 0.001574
#   vₜ (Adam 2nd moment) mean: 0.003010
#   mₜ (Adam 1st moment) mean: 0.000585
#   vₜ (Adam 2nd moment) mean: 0.000103
#   mₜ (Adam 1st moment) mean: 0.000464
#   vₜ (Adam 2nd moment) mean: 0.000250
#   mₜ (Adam 1st moment) mean: 0.000008
#   vₜ (Adam 2nd moment) mean: 0.000009
#   mₜ (Adam 1st moment) mean: 0.000015
#   vₜ (Adam 2nd moment) mean: 0.000006
#   mₜ (Adam 1st moment) mean: 0.000000
#   vₜ (Adam 2nd moment) mean: 0.000567
#   mₜ (Adam 1st moment) mean: 0.000000
#   vₜ (Adam 2nd moment) mean: 0.000052
# Epoch [5/5] J(θ) = 0.0414
#
# Training with optimizer: Adagrad
#
# Epoch 1 (Optimizer: Adagrad)
#   ∇J(conv1.weight) = grad norm: 0.015169
#   ∇J(conv1.bias) = grad norm: 0.009838
#   ∇J(conv2.weight) = grad norm: 0.054321
#   ∇J(conv2.bias) = grad norm: 0.024025
#   ∇J(fc1.weight) = grad norm: 0.143281
#   ∇J(fc1.bias) = grad norm: 0.050008
#   ∇J(fc2.weight) = grad norm: 0.057343
#   ∇J(fc2.bias) = grad norm: 0.126145
#   Gₜ (Adagrad sum of grads²) mean: 0.000000
#   Gₜ (Adagrad sum of grads²) mean: 0.000000
#   Gₜ (Adagrad sum of grads²) mean: 0.000000
#   Gₜ (Adagrad sum of grads²) mean: 0.000000
#   Gₜ (Adagrad sum of grads²) mean: 0.000000
#   Gₜ (Adagrad sum of grads²) mean: 0.000000
#   Gₜ (Adagrad sum of grads²) mean: 0.000000
#   Gₜ (Adagrad sum of grads²) mean: 0.000000
# Epoch [1/5] J(θ) = 0.2549
#
# Epoch 2 (Optimizer: Adagrad)
#   ∇J(conv1.weight) = grad norm: 0.054460
#   ∇J(conv1.bias) = grad norm: 0.043529
#   ∇J(conv2.weight) = grad norm: 0.206250
#   ∇J(conv2.bias) = grad norm: 0.031978
#   ∇J(fc1.weight) = grad norm: 0.514394
#   ∇J(fc1.bias) = grad norm: 0.017057
#   ∇J(fc2.weight) = grad norm: 0.834080
#   ∇J(fc2.bias) = grad norm: 0.026217
#   Gₜ (Adagrad sum of grads²) mean: 0.336236
#   Gₜ (Adagrad sum of grads²) mean: 1.994437
#   Gₜ (Adagrad sum of grads²) mean: 0.120056
#   Gₜ (Adagrad sum of grads²) mean: 0.342181
#   Gₜ (Adagrad sum of grads²) mean: 0.021100
#   Gₜ (Adagrad sum of grads²) mean: 0.016150
#   Gₜ (Adagrad sum of grads²) mean: 2.444738
#   Gₜ (Adagrad sum of grads²) mean: 0.252411
# Epoch [2/5] J(θ) = 0.1197
#
# Epoch 3 (Optimizer: Adagrad)
#   ∇J(conv1.weight) = grad norm: 0.098523
#   ∇J(conv1.bias) = grad norm: 0.089197
#   ∇J(conv2.weight) = grad norm: 0.273645
#   ∇J(conv2.bias) = grad norm: 0.042581
#   ∇J(fc1.weight) = grad norm: 0.452197
#   ∇J(fc1.bias) = grad norm: 0.013321
#   ∇J(fc2.weight) = grad norm: 0.704271
#   ∇J(fc2.bias) = grad norm: 0.017446
#   Gₜ (Adagrad sum of grads²) mean: 0.556172
#   Gₜ (Adagrad sum of grads²) mean: 3.496383
#   Gₜ (Adagrad sum of grads²) mean: 0.236865
#   Gₜ (Adagrad sum of grads²) mean: 0.541066
#   Gₜ (Adagrad sum of grads²) mean: 0.035805
#   Gₜ (Adagrad sum of grads²) mean: 0.022765
#   Gₜ (Adagrad sum of grads²) mean: 3.863117
#   Gₜ (Adagrad sum of grads²) mean: 0.337854
# Epoch [3/5] J(θ) = 0.0985
#
# Epoch 4 (Optimizer: Adagrad)
#   ∇J(conv1.weight) = grad norm: 0.078977
#   ∇J(conv1.bias) = grad norm: 0.034049
#   ∇J(conv2.weight) = grad norm: 0.171465
#   ∇J(conv2.bias) = grad norm: 0.023097
#   ∇J(fc1.weight) = grad norm: 0.297440
#   ∇J(fc1.bias) = grad norm: 0.008456
#   ∇J(fc2.weight) = grad norm: 0.396972
#   ∇J(fc2.bias) = grad norm: 0.009939
#   Gₜ (Adagrad sum of grads²) mean: 0.779620
#   Gₜ (Adagrad sum of grads²) mean: 5.057918
#   Gₜ (Adagrad sum of grads²) mean: 0.360967
#   Gₜ (Adagrad sum of grads²) mean: 0.724318
#   Gₜ (Adagrad sum of grads²) mean: 0.050224
#   Gₜ (Adagrad sum of grads²) mean: 0.028545
#   Gₜ (Adagrad sum of grads²) mean: 5.168643
#   Gₜ (Adagrad sum of grads²) mean: 0.410162
# Epoch [4/5] J(θ) = 0.0868
#
# Epoch 5 (Optimizer: Adagrad)
#   ∇J(conv1.weight) = grad norm: 0.126221
#   ∇J(conv1.bias) = grad norm: 0.107401
#   ∇J(conv2.weight) = grad norm: 0.413418
#   ∇J(conv2.bias) = grad norm: 0.054173
#   ∇J(fc1.weight) = grad norm: 0.367048
#   ∇J(fc1.bias) = grad norm: 0.012600
#   ∇J(fc2.weight) = grad norm: 0.483814
#   ∇J(fc2.bias) = grad norm: 0.015618
#   Gₜ (Adagrad sum of grads²) mean: 1.012287
#   Gₜ (Adagrad sum of grads²) mean: 6.547319
#   Gₜ (Adagrad sum of grads²) mean: 0.487665
#   Gₜ (Adagrad sum of grads²) mean: 0.889375
#   Gₜ (Adagrad sum of grads²) mean: 0.064377
#   Gₜ (Adagrad sum of grads²) mean: 0.033629
#   Gₜ (Adagrad sum of grads²) mean: 6.364078
#   Gₜ (Adagrad sum of grads²) mean: 0.471783
# Epoch [5/5] J(θ) = 0.0790
# Final Test Accuracy: 97.82%

# %% [markdown]
# **Gradient Descent Variants — Theoretical Update Formulas**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Terms:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is loss here?**
#
# It’s a numerical measure of how wrong our model’s predictions are.
#
#
# In CNN above, we are using:  Softmax + negative log likelihood (nn.CrossEntropyLoss())
#
# Softmax turns this into probabilities: Loss = - log(p_model(correct class))

# %%
# Re-import after kernel reset
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
import random

# Set seeds
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# Load data
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)

# CNN model
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.fc1 = nn.Linear(16*5*5, 64)
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 16*5*5)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Helper functions
def get_param_vector(model):
    return torch.cat([p.data.view(-1) for p in model.parameters()])

def predict_samples(model, dataset, num=5):
    model.eval()
    fig, axes = plt.subplots(1, num, figsize=(12, 3))
    for i in range(num):
        image, label = dataset[i]
        input_img = image.unsqueeze(0)
        output = model(input_img)
        pred = torch.argmax(output, dim=1).item()
        axes[i].imshow(image.squeeze(), cmap='gray')
        axes[i].set_title(f"True: {label}\nPred: {pred}")
        axes[i].axis('off')
    plt.suptitle("Sample Predictions")
    plt.show()

def train_and_track(optimizer_name, model, train_loader, criterion, epochs=5):
    model.train()
    param_trajectory = []
    loss_trajectory = []

    if optimizer_name == 'GD':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
        use_batches = False
    elif optimizer_name == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
        use_batches = True
    elif optimizer_name == 'Momentum':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
        use_batches = True
    elif optimizer_name == 'RMSProp':
        optimizer = torch.optim.RMSprop(model.parameters(), lr=0.001)
        use_batches = True
    elif optimizer_name == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        use_batches = True
    elif optimizer_name == 'Adagrad':
        optimizer = torch.optim.Adagrad(model.parameters(), lr=0.01)
        use_batches = True
    else:
        raise ValueError("Unsupported optimizer")

    print(f"\nTraining with optimizer: {optimizer_name}")
    for epoch in range(epochs):
        running_loss = 0.0
        if not use_batches:
            images, labels = next(iter(train_loader))
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss = loss.item()
        else:
            for images, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()

        avg_loss = running_loss / (1 if not use_batches else len(train_loader))
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}")
        param_vector = get_param_vector(model).detach().cpu().numpy()
        param_trajectory.append(param_vector)
        loss_trajectory.append(avg_loss)

    return np.array(param_trajectory), np.array(loss_trajectory), model

def evaluate(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# Train with all optimizers
optimizers = ['GD', 'SGD', 'Momentum', 'RMSProp', 'Adam', 'Adagrad']
trajectories = {}
criterion = nn.CrossEntropyLoss()

for opt_name in optimizers:
    model = SimpleCNN()
    traj, losses, trained_model = train_and_track(opt_name, model, train_loader, criterion, epochs=5)
    trajectories[opt_name] = {'trajectory': traj, 'losses': losses, 'model': trained_model}

# Plot 2D loss curves
plt.figure(figsize=(10, 6))
for opt_name in optimizers:
    losses = trajectories[opt_name]['losses']
    plt.plot(range(1, len(losses)+1), losses, label=opt_name)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs Epochs for Different Optimizers')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 3D plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
for opt_name in optimizers:
    traj = trajectories[opt_name]['trajectory']
    pca = PCA(n_components=2)
    reduced = pca.fit_transform(traj)
    z = trajectories[opt_name]['losses']
    ax.plot(reduced[:, 0], reduced[:, 1], z, label=opt_name)
ax.set_title('3D Optimization Trajectory (PCA + Loss)')
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel('Loss')
ax.legend()
plt.tight_layout()
plt.show()

# Final evaluation on the last trained model
accuracy = evaluate(trained_model, test_loader)
print(f"\nTest Accuracy: {accuracy * 100:.2f}%")
predict_samples(trained_model, test_dataset)
# Out:
# Training with optimizer: GD
# Epoch [1/5], Loss: 2.2926
# Epoch [2/5], Loss: 2.3080
# Epoch [3/5], Loss: 2.3167
# Epoch [4/5], Loss: 2.2967
# Epoch [5/5], Loss: 2.3090
#
# Training with optimizer: SGD
# Epoch [1/5], Loss: 1.4147
# Epoch [2/5], Loss: 0.3455
# Epoch [3/5], Loss: 0.2352
# Epoch [4/5], Loss: 0.1774
# Epoch [5/5], Loss: 0.1421
#
# Training with optimizer: Momentum
# Epoch [1/5], Loss: 0.3770
# Epoch [2/5], Loss: 0.0881
# Epoch [3/5], Loss: 0.0658
# Epoch [4/5], Loss: 0.0511
# Epoch [5/5], Loss: 0.0438
#
# Training with optimizer: RMSProp
# Epoch [1/5], Loss: 0.2257
# Epoch [2/5], Loss: 0.0888
# Epoch [3/5], Loss: 0.0650
# Epoch [4/5], Loss: 0.0523
# Epoch [5/5], Loss: 0.0431
#
# Training with optimizer: Adam
# Epoch [1/5], Loss: 0.3070
# Epoch [2/5], Loss: 0.0869
# Epoch [3/5], Loss: 0.0616
# Epoch [4/5], Loss: 0.0493
# Epoch [5/5], Loss: 0.0414
#
# Training with optimizer: Adagrad
# Epoch [1/5], Loss: 0.2549
# Epoch [2/5], Loss: 0.1197
# Epoch [3/5], Loss: 0.0985
# Epoch [4/5], Loss: 0.0868
# Epoch [5/5], Loss: 0.0790
# Test Accuracy: 97.82%

# %%
2. CIFAR-10

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
import random

# Set seeds
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# Load CIFAR10 data
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transform, download=True)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transform, download=True)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)


# Display total dataset sizes
total_train = len(train_dataset)
total_test = len(test_dataset)

# Show a few sample images
def show_sample_images(dataset, num_images=6):
    fig, axes = plt.subplots(1, num_images, figsize=(12, 2))
    for i in range(num_images):
        image, label = dataset[i]
        axes[i].imshow(image.squeeze(), cmap='gray')
        axes[i].set_title(f"Label: {label}")
        axes[i].axis('off')
    plt.suptitle("Sample CIFAR10 Images")
    plt.show()

# CNN model
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 8, kernel_size=3)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.fc1 = nn.Linear(16*5*5, 64)
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        # x = x.view(-1, 16*5*5)
        x = x.view(x.size(0), -1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Utility functions
def get_param_vector(model):
    return torch.cat([p.data.view(-1) for p in model.parameters()])

def predict_samples(model, dataset, num=5):
    model.eval()
    fig, axes = plt.subplots(1, num, figsize=(12, 3))
    for i in range(num):
        image, label = dataset[i]
        input_img = image.unsqueeze(0)
        output = model(input_img)
        pred = torch.argmax(output, dim=1).item()
        axes[i].imshow(image.squeeze(), cmap='gray')
        axes[i].set_title(f"True: {label}\nPred: {pred}")
        axes[i].axis('off')
    plt.suptitle("Sample Predictions")
    plt.show()

# Train model and print internal state
def train_and_track(optimizer_name, model, train_loader, criterion, epochs=5):
    model.train()
    param_trajectory = []
    loss_trajectory = []

    if optimizer_name == 'GD':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
        use_batches = False
    elif optimizer_name == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
        use_batches = True
    elif optimizer_name == 'Momentum':
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
        use_batches = True
    elif optimizer_name == 'RMSProp':
        optimizer = torch.optim.RMSprop(model.parameters(), lr=0.001)
        use_batches = True
    elif optimizer_name == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        use_batches = True
    elif optimizer_name == 'Adagrad':
        optimizer = torch.optim.Adagrad(model.parameters(), lr=0.01)
        use_batches = True
    else:
        raise ValueError("Unsupported optimizer")

    print(f"\nTraining with optimizer: {optimizer_name}")
    for epoch in range(epochs):
        running_loss = 0.0
        first_batch = True

        if not use_batches:
            images, labels = next(iter(train_loader))
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss = loss.item()
        else:
            for images, labels in train_loader:
                optimizer.zero_grad()
                outputs = model(images)
                loss = criterion(outputs, labels)
                loss.backward()

                if first_batch:
                    print(f"\nEpoch {epoch+1} (Optimizer: {optimizer_name})")
                    for name, param in model.named_parameters():
                        if param.grad is not None:
                            print(f"  ∇J({name}) = grad norm: {param.grad.norm():.6f}")
                    for group in optimizer.param_groups:
                        for p in group['params']:
                            state = optimizer.state[p]
                            if optimizer_name == 'Momentum' and 'momentum_buffer' in state:
                                v = state['momentum_buffer']
                                print(f"  v (momentum) mean: {v.mean().item():.6f}")
                            if optimizer_name == 'RMSProp' and 'square_avg' in state:
                                s = state['square_avg']
                                print(f"  s (RMSProp avg^2) mean: {s.mean().item():.6f}")
                            if optimizer_name == 'Adam' and 'exp_avg' in state:
                                m = state['exp_avg']
                                v = state['exp_avg_sq']
                                print(f"  mₜ (Adam 1st moment) mean: {m.mean().item():.6f}")
                                print(f"  vₜ (Adam 2nd moment) mean: {v.mean().item():.6f}")
                            if optimizer_name == 'Adagrad' and 'sum' in state:
                                G = state['sum']
                                print(f"  Gₜ (Adagrad sum of grads²) mean: {G.mean().item():.6f}")
                    first_batch = False

                optimizer.step()
                running_loss += loss.item()

        avg_loss = running_loss / (1 if not use_batches else len(train_loader))
        print(f"Epoch [{epoch+1}/{epochs}] J(θ) = {avg_loss:.4f}")

        param_vector = get_param_vector(model).detach().cpu().numpy()
        param_trajectory.append(param_vector)
        loss_trajectory.append(avg_loss)

    return np.array(param_trajectory), np.array(loss_trajectory), model

# Accuracy eval
def evaluate(model, test_loader):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# Run training for all optimizers
optimizers = ['GD', 'SGD', 'Momentum', 'RMSProp', 'Adam', 'Adagrad']
trajectories = {}
criterion = nn.CrossEntropyLoss()

for opt_name in optimizers:
    model = SimpleCNN()
    traj, losses, trained_model = train_and_track(opt_name, model, train_loader, criterion, epochs=5)
    trajectories[opt_name] = {'trajectory': traj, 'losses': losses, 'model': trained_model}

# 2D Loss plot
plt.figure(figsize=(10, 6))
for opt_name in optimizers:
    losses = trajectories[opt_name]['losses']
    plt.plot(range(1, len(losses)+1), losses, label=opt_name)
plt.xlabel('Epoch')
plt.ylabel('Loss J(θ)')
plt.title('Loss vs Epochs for Different Optimizers')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 3D PCA Trajectory
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
for opt_name in optimizers:
    traj = trajectories[opt_name]['trajectory']
    pca = PCA(n_components=2)
    reduced = pca.fit_transform(traj)
    z = trajectories[opt_name]['losses']
    ax.plot(reduced[:, 0], reduced[:, 1], z, label=opt_name)
ax.set_title('3D Optimization Trajectory (PCA + J(θ))')
ax.set_xlabel('PCA 1')
ax.set_ylabel('PCA 2')
ax.set_zlabel('Loss J(θ)')
ax.legend()
plt.tight_layout()
plt.show()

# Final evaluation
accuracy = evaluate(trained_model, test_loader)
print(f"\nFinal Test Accuracy: {accuracy * 100:.2f}%")
predict_samples(trained_model, test_dataset)
