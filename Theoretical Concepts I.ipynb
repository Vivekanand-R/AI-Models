# %% [markdown]
# **List of Algorithm, Method, and Theory**
#
# 1. BFGS algorithm → Quasi-Newton optimization method
# 2. Diagonal approximation → Simplified Hessian estimate
# 3. Quasi-Newton methods → Gradient-based Hessian approximation
# 4. Newton’s method → Iterative root-finding algorithm
# 5. Sherman-Morrison formula → Fast matrix inverse update
# 6. Universal Approximation Theorem → Neural networks approximate functions
# 7. Random Matrix Theory → Statistics of random matrices
# 8. Quarter circular law → Eigenvalue distribution law

# %% [markdown]
# **Generic Facts about Universal Approximation Theorem (UAT):**
#
# UAT was first proved in 1989 by George Cybenko for sigmoid activation functions.
#
# It states that a feedforward neural network with at least one hidden layer can approximate any continuous function on a compact set.
#
# The theorem shows the expressive power of NNs, not their training efficiency.
#
# It applies to a wide class of activation functions, including sigmoid, ReLU, and tanh.
#
# UAT guarantees existence of weights, but not how to find them.
#
# It only applies to continuous functions, not arbitrary discontinuous ones.
#
# Compact set means the function is bounded and closed in its domain.
#
# A neural network can approximate with arbitrary accuracy if allowed enough hidden units.
#
# UAT is independent of optimization algorithms like gradient descent.
#
# The result is mathematical and does not imply practical efficiency.
#
# It does not specify the size of the network required for approximation.
#
# A single hidden layer is theoretically enough, but may require an exponential number of neurons.
#
# Deeper architectures may approximate functions with fewer neurons than shallow ones.
#
# UAT is a foundation for why neural networks are powerful universal models.
#
# It applies to both regression and classification tasks indirectly.
#
# The error bound can be made arbitrarily small, but not necessarily zero.
#
# UAT relates to the "expressive completeness" of neural nets.
#
# The theorem inspired many advances in deep learning.
#
# In practice, optimization and generalization issues matter more than UAT guarantees.
#
# UAT is one of the main theoretical justifications for using neural networks widely.

# %% [markdown]
# **Theoretical Facts about Universal Approximation Theorem (UAT):**
#
# Cybenko (1989) proved UAT for sigmoid activation functions on
# [
# 0
# ,
# 1
# ]
# 𝑛
# [0,1]
# n
# .
#
# Hornik (1991) generalized UAT to a wide class of non-polynomial activation functions.
#
# UAT requires that the activation function be non-linear; otherwise, only linear functions can be approximated.
#
# For ReLU networks, UAT also holds but with different constructive proofs.
#
# The Stone–Weierstrass theorem is a mathematical foundation related to UAT.
#
# The proof often uses density arguments in function spaces.
#
# UAT does not give computational complexity bounds on how many neurons are needed.
#
# It guarantees approximation in
# 𝐿
# 𝑝
# L
# p
#  norms, not just pointwise convergence.
#
# The approximation is valid only on compact domains, not unbounded ones.
#
# The activation function must be bounded, measurable, and non-constant (for Cybenko’s version).
#
# Radial basis function (RBF) networks also satisfy UAT.
#
# UAT applies to multilayer perceptrons (MLPs), not just shallow NNs.
#
# Deep NNs can approximate some functions exponentially more efficiently than shallow ones.
#
# The UAT does not address generalization to unseen data.
#
# It is related to the concept of "function space universality."
#
# Polynomial functions are also universal approximators by the Weierstrass approximation theorem.
#
# The proof constructs approximations by partitioning the input space into regions.
#
# In measure-theoretic sense, UAT holds almost everywhere for integrable functions.
#
# Approximation rate (how fast error decreases with neurons) is not given by UAT.
#
# UAT is often extended to probabilistic spaces, e.g., approximation in distribution.
